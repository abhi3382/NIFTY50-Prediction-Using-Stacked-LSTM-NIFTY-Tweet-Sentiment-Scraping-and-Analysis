# %%
# !pip install snscrape
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# import snscrape.modules.twitter as sntwitter
# import pandas as pd

# query = "#nifty50 until:2022-09-05 since:2017-09-01"
# tweets = []
# limit = 5000000000


# for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
#     # print(vars(tweet))
#     # break
#     if len(tweets) == limit:
#         break
#     else:
#         tweets.append([tweet.content,tweet.date])
        
# df = pd.DataFrame(tweets, columns=['Tweet','Date'])
# print(df)

# # # to save to csv
# # # df.to_csv('tweets.csv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-caa3e5176b22> in <module>
#       7
#       8
# ----> 9 for tweet in sntwitter.TwitterSearchScraper(query).get_items():
#      10
#      11     # print(vars(tweet))
#
# ...

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# %%
import datetime as dt
from datetime import timedelta
from datetime import datetime

# %%
tweets = []

# %%
tweets_df = pd.DataFrame(columns=['Tweet','Date'])

# %%
first_date = dt.date(2017, 9, 1)
second_date = dt.date(2022, 9, 5)

# %%
# for x in range(1830):
#     print(str(second_date))
#     second_date -= timedelta(days=1)
#     for i,tweet in enumerate(sntwitter.TwitterSearchScraper('#nifty50 since:'+str(first_date)+' until:'+str(second_date)).get_items()):
#         if i>4:
#             break
#         if x < 1830:
#             tweets_df = tweets_df.append({'Tweet' : tweet.content, 'Date' : tweet.date},ignore_index=True)
#         else:
#             break
# Out:
# 2022-09-05
# 2022-09-04
# 2022-09-03
# 2022-09-02
# 2022-09-01
# 2022-08-31
# 2022-08-30
# 2022-08-29
# 2022-08-28
# 2022-08-27
# 2022-08-26
# 2022-08-25
# 2022-08-24
# 2022-08-23
# 2022-08-22
# 2022-08-21
# 2022-08-20
# 2022-08-19
# 2022-08-18
# 2022-08-17
# 2022-08-16
# 2022-08-15
# 2022-08-14
# 2022-08-13
# 2022-08-12
# 2022-08-11
# 2022-08-10
# 2022-08-09
# 2022-08-08
# 2022-08-07
# 2022-08-06
# 2022-08-05
# 2022-08-04
# 2022-08-03
# 2022-08-02
# 2022-08-01
# 2022-07-31
# 2022-07-30
# 2022-07-29
# 2022-07-28
# 2022-07-27
# 2022-07-26
# 2022-07-25
# 2022-07-24
# 2022-07-23
# 2022-07-22
# 2022-07-21
# 2022-07-20
# 2022-07-19
# 2022-07-18
# 2022-07-17
# 2022-07-16
# 2022-07-15
# 2022-07-14
# 2022-07-13
# 2022-07-12
# 2022-07-11
# 2022-07-10
# 2022-07-09
# 2022-07-08
# 2022-07-07
# 2022-07-06
# 2022-07-05
# 2022-07-04
# 2022-07-03
# 2022-07-02
# 2022-07-01
# 2022-06-30
# 2022-06-29
# 2022-06-28
# 2022-06-27
# 2022-06-26
# 2022-06-25
# 2022-06-24
# 2022-06-23
# 2022-06-22
# ...

# %%
first_date = dt.date(2017, 9, 1)
second_date = dt.date(2019, 12, 10)

# %%
for x in range(1830):
    print(str(second_date))
    second_date -= timedelta(days=1)
    for i,tweet in enumerate(sntwitter.TwitterSearchScraper('#nifty50 since:'+str(first_date)+' until:'+str(second_date)).get_items()):
        if i>4:
            break
        if x < 1830:
            tweets_df = tweets_df.append({'Tweet' : tweet.content, 'Date' : tweet.date},ignore_index=True)
        else:
            break
# Out:
# 2019-12-10
# ---------------------------------------------------------------------------
# ScraperException                          Traceback (most recent call last)
# <ipython-input-28-519d2f1635e0> in <module>
#       2     print(str(second_date))
#       3     second_date -= timedelta(days=1)
# ----> 4     for i,tweet in enumerate(sntwitter.TwitterSearchScraper('#nifty50 since:'+str(first_date)+' until:'+str(second_date)).get_items()):
#       5         if i>4:
#       6             break
#
# /usr/local/lib/python3.7/dist-packages/snscrape/modules/twitter.py in get_items(self)
#     129                 while True:
#     130                         if not guestToken:
# --> 131                                 guestToken = self._get_guest_token()
#     132                                 self._session.cookies.set('gt', guestToken, domain = '.twitter.com', path = '/', secure = True, expires = time.time() + 10800)
# ...

# %%
tweets_df
# Out:
# Empty DataFrame
# Columns: [Tweet, Date]
# Index: []

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Mounted at drive

# %%
# tweets_df.to_csv('tweets_2019_dec.csv', sep='\t', encoding='utf-8')
# !cp tweets_2019_dec.csv "drive/My Drive/"

# %%
# tweets_df = pd.DataFrame(columns=['Tweet','Date'])

# %%
# first_date = dt.date(2017, 9, 1)
# second_date = dt.date(2019, 12, 10)

# %%
# for x in range(801):  # Days from 10 Dec 2019 to 1 sep 2017
#     print(str(second_date))
#     second_date -= timedelta(days=1)
#     for i,tweet in enumerate(sntwitter.TwitterSearchScraper('#nifty50 since:'+str(first_date)+' until:'+str(second_date)).get_items()):
#         if i>4:
#             break
#         if x < 1830:
#             tweets_df = tweets_df.append({'Tweet' : tweet.content, 'Date' : tweet.date},ignore_index=True)
#         else:
#             break

# %%
# tweets_df.to_csv('tweets_2017.csv', sep='\t', encoding='utf-8')
# !cp tweets_2017.csv "drive/My Drive/"

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-c0e8af41-c4fc-42de-addb-08480e6ad244" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c0e8af41-c4fc-42de-addb-08480e6ad244">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df1 = pd.read_csv(r"tweets_2019_dec (1).csv")

# %%
upload = files.upload()
# Out:
#      <input type="file" id="files-7162d1e9-1d6f-4ac9-b205-bad8f7eb1e7e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7162d1e9-1d6f-4ac9-b205-bad8f7eb1e7e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df2 = pd.read_csv(r"tweets_2017.csv")

# %%
df = pd.concat([df1, df2], axis=0)

# %%
df
# Out:
#      Unnamed: 0                                              Tweet  \
# 0             0  #intradaytrading #Nifty #BANKNIFTY #optiontrad...
# 1             1  78K+ on Thursday Expiry. Carried #nifty50 Puts...
# 2             2  STOCK TO WATCH\nHINDALCO\nin range \nEDUCATION...
# 3             3  GRASIM INDUSTRIES\nReady to BREAKOUT\nWith Vol...
# 4             4  People were avoiding Adani companies for over-...
# ...         ...                                                ...
# 4146       4140  @AIM_Buster Sir, I think, U r talking about #N...
# 4147       4141  #NIFTY50 #Nifty #IND50 SHORT in red box https:...
# 4148       4142  Happy trading \n#Nifty #NIFTYFUTURE #nifty50 #...
# 4149       4143  Happy trading \n#Nifty #NIFTYFUTURE #nifty50 #...
# 4150       4144  # naturalgas low 192.30 enjoy profit for more ...
#
#                            Date
# 0     2022-09-03 23:58:08+00:00
# 1     2022-09-03 21:20:50+00:00
# 2     2022-09-03 21:20:08+00:00
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#      Unnamed: 0                                              Tweet  \
# 0             0  #intradaytrading #Nifty #BANKNIFTY #optiontrad...
# 1             1  78K+ on Thursday Expiry. Carried #nifty50 Puts...
# 2             2  STOCK TO WATCH\nHINDALCO\nin range \nEDUCATION...
# 3             3  GRASIM INDUSTRIES\nReady to BREAKOUT\nWith Vol...
# 4             4  People were avoiding Adani companies for over-...
# ...         ...                                                ...
# 9141       4140  @AIM_Buster Sir, I think, U r talking about #N...
# 9142       4141  #NIFTY50 #Nifty #IND50 SHORT in red box https:...
# 9143       4142  Happy trading \n#Nifty #NIFTYFUTURE #nifty50 #...
# 9144       4143  Happy trading \n#Nifty #NIFTYFUTURE #nifty50 #...
# 9145       4144  # naturalgas low 192.30 enjoy profit for more ...
#
#                            Date
# 0     2022-09-03 23:58:08+00:00
# 1     2022-09-03 21:20:50+00:00
# 2     2022-09-03 21:20:08+00:00
# ...

# %%
df['Unnamed: 0']
# Out:
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 9141    4140
# 9142    4141
# 9143    4142
# 9144    4143
# 9145    4144
# Name: Unnamed: 0, Length: 9146, dtype: object

# %%
df = df.drop('Unnamed: 0',axis=1)

# %%
df
# Out:
#                                                   Tweet  \
# 0     #intradaytrading #Nifty #BANKNIFTY #optiontrad...
# 1     78K+ on Thursday Expiry. Carried #nifty50 Puts...
# 2     STOCK TO WATCH\nHINDALCO\nin range \nEDUCATION...
# 3     GRASIM INDUSTRIES\nReady to BREAKOUT\nWith Vol...
# 4     People were avoiding Adani companies for over-...
# ...                                                 ...
# 9141  @AIM_Buster Sir, I think, U r talking about #N...
# 9142  #NIFTY50 #Nifty #IND50 SHORT in red box https:...
# 9143  Happy trading \n#Nifty #NIFTYFUTURE #nifty50 #...
# 9144  Happy trading \n#Nifty #NIFTYFUTURE #nifty50 #...
# 9145  # naturalgas low 192.30 enjoy profit for more ...
#
#                            Date
# 0     2022-09-03 23:58:08+00:00
# 1     2022-09-03 21:20:50+00:00
# 2     2022-09-03 21:20:08+00:00
# 3     2022-09-03 21:12:35+00:00
# 4     2022-09-03 20:54:09+00:00
# ...                         ...
# 9141  2017-09-01 17:57:49+00:00
# ...

# %%
df.to_csv('tweets_final1.csv', sep='\t', encoding='utf-8')
# !cp tweets_final1.csv "drive/My Drive/"

# %%
first_date = dt.date(2017, 1, 2)
second_date = dt.date(2017, 9, 1)

# %%
for x in range(280):
    print(str(second_date))
    second_date -= timedelta(days=1)
    for i,tweet in enumerate(sntwitter.TwitterSearchScraper('#nifty50 since:'+str(first_date)+' until:'+str(second_date)).get_items()):
        if i>4:
            break
        if x < 280:
            tweets_df = tweets_df.append({'Tweet' : tweet.content, 'Date' : tweet.date},ignore_index=True)
        else:
            break
# Out:
# 2017-09-01
# 2017-08-31
# 2017-08-30
# 2017-08-29
# 2017-08-28
# 2017-08-27
# 2017-08-26
# 2017-08-25
# 2017-08-24
# 2017-08-23
# 2017-08-22
# 2017-08-21
# 2017-08-20
# 2017-08-19
# 2017-08-18
# 2017-08-17
# 2017-08-16
# 2017-08-15
# 2017-08-14
# 2017-08-13
# 2017-08-12
# 2017-08-11
# 2017-08-10
# 2017-08-09
# 2017-08-08
# 2017-08-07
# 2017-08-06
# 2017-08-05
# 2017-08-04
# 2017-08-03
# 2017-08-02
# 2017-08-01
# 2017-07-31
# 2017-07-30
# 2017-07-29
# 2017-07-28
# 2017-07-27
# 2017-07-26
# 2017-07-25
# 2017-07-24
# 2017-07-23
# 2017-07-22
# 2017-07-21
# 2017-07-20
# 2017-07-19
# 2017-07-18
# 2017-07-17
# 2017-07-16
# 2017-07-15
# 2017-07-14
# 2017-07-13
# 2017-07-12
# 2017-07-11
# 2017-07-10
# 2017-07-09
# 2017-07-08
# 2017-07-07
# 2017-07-06
# 2017-07-05
# 2017-07-04
# 2017-07-03
# 2017-07-02
# 2017-07-01
# 2017-06-30
# 2017-06-29
# 2017-06-28
# 2017-06-27
# 2017-06-26
# 2017-06-25
# 2017-06-24
# 2017-06-23
# 2017-06-22
# 2017-06-21
# 2017-06-20
# 2017-06-19
# 2017-06-18
# ...

# %%
tweets_df
# Out:
#                                                   Tweet  \
# 0     Impressive setup for  $FB on https://t.co/WrwB...
# 1     Nifty seems to be Open @  ?\n\n@NSEIndia @BSEI...
# 2     Nifty seems Gap Up Open @ 9940 ?\n\n@NSEIndia ...
# 3     #Sensex 300 points rally highlights the spirit...
# 4     Impressive setup for  $EXC on https://t.co/bLw...
# ...                                                 ...
# 1200  #Sensex, #Nifty50 end 1st trading day of the y...
# 1201  #India stocks were lower after the close on Mo...
# 1202  #SENSEX SHEDS 150 POINTS; #NIFTY50 BELOW 8,150...
# 1203  #Sensex sheds 150 points; #Nifty50 below 8,150...
# 1204  #Sensex extends fall; #Nifty50 below 8,150. \n...
#
#                           Date
# 0    2017-08-30 21:09:03+00:00
# 1    2017-08-30 18:50:54+00:00
# 2    2017-08-30 18:46:19+00:00
# 3    2017-08-30 16:58:56+00:00
# 4    2017-08-30 16:07:03+00:00
# ...                        ...
# 1200 2017-01-02 12:43:25+00:00
# 1201 2017-01-02 12:19:38+00:00
# ...

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-a9519cb0-850d-416a-8f81-0182b45b88dd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a9519cb0-850d-416a-8f81-0182b45b88dd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv(r"tweets_final1.csv")

# %%
df = df.drop('Unnamed: 0',axis=1)

# %%
df
# Out:
#                                                   Tweet  \
# 0     #intradaytrading #Nifty #BANKNIFTY #optiontrad...
# 1     78K+ on Thursday Expiry. Carried #nifty50 Puts...
# 2     STOCK TO WATCH\nHINDALCO\nin range \nEDUCATION...
# 3     GRASIM INDUSTRIES\nReady to BREAKOUT\nWith Vol...
# 4     People were avoiding Adani companies for over-...
# ...                                                 ...
# 9141  @AIM_Buster Sir, I think, U r talking about #N...
# 9142  #NIFTY50 #Nifty #IND50 SHORT in red box https:...
# 9143  Happy trading \n#Nifty #NIFTYFUTURE #nifty50 #...
# 9144  Happy trading \n#Nifty #NIFTYFUTURE #nifty50 #...
# 9145  # naturalgas low 192.30 enjoy profit for more ...
#
#                            Date
# 0     2022-09-03 23:58:08+00:00
# 1     2022-09-03 21:20:50+00:00
# 2     2022-09-03 21:20:08+00:00
# 3     2022-09-03 21:12:35+00:00
# 4     2022-09-03 20:54:09+00:00
# ...                         ...
# 9141  2017-09-01 17:57:49+00:00
# ...

# %%
fin_df = pd.concat([df, tweets_df], axis=0)

# %%
fin_df
# Out:
#                                                   Tweet  \
# 0     #intradaytrading #Nifty #BANKNIFTY #optiontrad...
# 1     78K+ on Thursday Expiry. Carried #nifty50 Puts...
# 2     STOCK TO WATCH\nHINDALCO\nin range \nEDUCATION...
# 3     GRASIM INDUSTRIES\nReady to BREAKOUT\nWith Vol...
# 4     People were avoiding Adani companies for over-...
# ...                                                 ...
# 1200  #Sensex, #Nifty50 end 1st trading day of the y...
# 1201  #India stocks were lower after the close on Mo...
# 1202  #SENSEX SHEDS 150 POINTS; #NIFTY50 BELOW 8,150...
# 1203  #Sensex sheds 150 points; #Nifty50 below 8,150...
# 1204  #Sensex extends fall; #Nifty50 below 8,150. \n...
#
#                            Date
# 0     2022-09-03 23:58:08+00:00
# 1     2022-09-03 21:20:50+00:00
# 2     2022-09-03 21:20:08+00:00
# 3     2022-09-03 21:12:35+00:00
# 4     2022-09-03 20:54:09+00:00
# ...                         ...
# 1200  2017-01-02 12:43:25+00:00
# ...

# %%
fin_df.reset_index(drop=True, inplace=True)

# %%
fin_df
# Out:
#                                                    Tweet  \
# 0      #intradaytrading #Nifty #BANKNIFTY #optiontrad...
# 1      78K+ on Thursday Expiry. Carried #nifty50 Puts...
# 2      STOCK TO WATCH\nHINDALCO\nin range \nEDUCATION...
# 3      GRASIM INDUSTRIES\nReady to BREAKOUT\nWith Vol...
# 4      People were avoiding Adani companies for over-...
# ...                                                  ...
# 10346  #Sensex, #Nifty50 end 1st trading day of the y...
# 10347  #India stocks were lower after the close on Mo...
# 10348  #SENSEX SHEDS 150 POINTS; #NIFTY50 BELOW 8,150...
# 10349  #Sensex sheds 150 points; #Nifty50 below 8,150...
# 10350  #Sensex extends fall; #Nifty50 below 8,150. \n...
#
#                             Date
# 0      2022-09-03 23:58:08+00:00
# 1      2022-09-03 21:20:50+00:00
# 2      2022-09-03 21:20:08+00:00
# 3      2022-09-03 21:12:35+00:00
# 4      2022-09-03 20:54:09+00:00
# ...                          ...
# 10346  2017-01-02 12:43:25+00:00
# ...

# %%
fin_df.to_csv('dftweets_final1.csv', sep='\t', encoding='utf-8')
# !cp dftweets_final1.csv "drive/My Drive/"
